# %% [markdown]
# # <center><div class="alert alert-info">Simple Quiz</div>

# %%
name = input('Enter your name Contestant : ')
print()
print('Lets start the Quiz')
print()
ques1 = """1. Today the most popular social networking site is
 a. MySpace
 b. Twitter
 c. Weibo
 d. Facebook"""           
ques2 = """2. Which state held the most number of sittings of the State Assembly in 2021?
a. Tamil Nadu
b. Kerala
c. Odisha
d. Karnataka"""
ques3 = """3. Loktak Lake, the largest freshwater lake in India, is located in which state?
[A] Assam
[B] Manipur
[C] Haryana
[D] Telangana"""
ques4 = """4. Which shipyard built India’s first indigenous aircraft carrier— Vikrant?
[A] Cochin Shipyard
[B] Mazagon Dock Shipbuilders
[C] Garden Reach Shipbuilders & Engineers
[D] Hindustan Shipyard"""
ques5 = """5. Which state hosted the FIDE Chess Olympiad for the first time in India?
[A] Tamil Nadu
[B] Telangana
[C] Maharashtra
[D] Odisha"""
ques6 = """6. The Indian Navy recently received two MH-60 R multirole helicopters from which country?
[A] Russia
[B] United States
[C] Israel
[D] France"""
ques7 = """7. What is the name of the new application launched by UIDAI to authenticate Aadhar number with face?
[A] Aadhaar Face RD
[B] UIDAI Facetime
[C] Aadhar Authenticate
[D] Digi-Aadhar"""
ques8 = """8. Which state is associated with the ‘Family Doctor’ pilot project?
[A] Kerala
[B] Andhra Pradesh
[C] Tamil Nadu
[D] Karnataka"""
ques9 = """9. Which country successfully launched its space station module called ‘Wentian’?
[A] Russia
[B] Israel
[C] China
[D] UAE"""
ques10= """10. Which Indian state has instituted district climate change missions (DCCM)?
[A] Himachal Pradesh
[B] Assam
[C] Tamil Nadu
[D] Gujarat"""

ques = {ques1:'b',ques2:'b',ques3:'b',ques4:'a',ques5:'a',ques6:'b',ques7:'a',ques8:'b',ques9:'c',ques10:'c'}
sc = 0
for i in ques:
    print()
    print(i)
    choice = input('Do you want to skip this question ? ')
    if (choice=='yes') or (choice=='y'):
        continue
    a = input('Please enter the Correct answer from A or B or C or D : ')
    if (a == ques[i]):
        print()
        print('************************ You got the answer right, 1 points to you !! *****************************')
        sc = sc + 1
    else:
        print()
        print('************************ Sorry, its a wrong answer, points will be deducted. ****************************')
        sc = sc - 0.5
        print()

print(' ********************* Congrats !! ',name,', Your final score is : ',sc/len(ques)*100,'%',' **************************')
# Out:
# Enter your name Contestant : Rajesh
#
# Lets start the Quiz
#
#
# 1. Today the most popular social networking site is
#  a. MySpace
#  b. Twitter
#  c. Weibo
#  d. Facebook
# Do you want to skip this question ? n
# Please enter the Correct answer from A or B or C or D : b
#
# ************************ You got the answer right, 1 points to you !! *****************************
#
# 2. Which state held the most number of sittings of the State Assembly in 2021?
# a. Tamil Nadu
# b. Kerala
# c. Odisha
# d. Karnataka
# Do you want to skip this question ? a
# Please enter the Correct answer from A or B or C or D : a
#
# ************************ Sorry, its a wrong answer, points will be deducted. ****************************
#
#
# 3. Loktak Lake, the largest freshwater lake in India, is located in which state?
# [A] Assam
# [B] Manipur
# [C] Haryana
# [D] Telangana
# Do you want to skip this question ? b
# Please enter the Correct answer from A or B or C or D : b
#
# ...
